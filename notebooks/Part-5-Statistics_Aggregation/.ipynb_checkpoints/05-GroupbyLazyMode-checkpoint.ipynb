# %% [markdown]
# # Groupby 4: The `LazyGroupBy` object
# By the end of this section you will be able to:
# - do `groupby` in lazy mode
# - do aggregations on a `LazyGroupBy`
# - inspect the optimized query plan
# - profile a query

# %%
import polars as pl

# %%
csvFile = "../data/titanic.csv"

# %% [markdown]
# ## Creating a `LazyGroupBy` object

# %% [markdown]
# We create a `LazyGroupBy` object by calling `groupby` on a `LazyFrame`

# %%
(
    pl.scan_csv(csvFile)
    .groupby('Pclass')
)

# %% [markdown]
# ## Aggregations
# The only way to do aggregations on a `LazyGroupBy` is with `agg`. We cannot call, for example, `.mean` on `.groubpy` as we can with an eager groupby.
#
# Calling `agg` converts a `LazyGroupBy` to a `LazyFrame`

# %%
(
    pl.scan_csv(csvFile)
    .groupby('Pclass')
    .agg(
        pl.col("Age").mean()
    )
)
# Out:
# <h4>NAIVE QUERY PLAN</h4><p>run <b>LazyFrame.show_graph()</b> to see the optimized version</p><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 8.0.5 (20230430.1635)
#  -->
# <!-- Title: polars_query Pages: 1 -->
# <svg width="190pt" height="159pt"
#  viewBox="0.00 0.00 189.75 159.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 155)">
# <title>polars_query</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-155 185.75,-155 185.75,4 -4,4"/>
# <!-- AGG [col(&quot;Age&quot;).mean()]
# BY
# [col(&quot;Pclass&quot;)] [(0, 0)] [(0, 0)] -->
# <g id="node1" class="node">
# <title>AGG [col(&quot;Age&quot;).mean()]
# BY
# [col(&quot;Pclass&quot;)] [(0, 0)] [(0, 0)]</title>
# <polygon fill="none" stroke="black" points="171.25,-151 10.5,-151 10.5,-93.5 171.25,-93.5 171.25,-151"/>
# <text text-anchor="middle" x="90.88" y="-133.7" font-family="Times,serif" font-size="14.00">AGG [col(&quot;Age&quot;).mean()]</text>
# <text text-anchor="middle" x="90.88" y="-117.2" font-family="Times,serif" font-size="14.00">BY</text>
# <text text-anchor="middle" x="90.88" y="-100.7" font-family="Times,serif" font-size="14.00">[col(&quot;Pclass&quot;)] [(0, 0)]</text>
# </g>
# <!-- CSV SCAN ../data/titanic.csv;
# π */12;
# σ &#45; [(0, 1)] -->
# <g id="node2" class="node">
# <title>CSV SCAN ../data/titanic.csv;
# π */12;
# σ &#45; [(0, 1)]</title>
# <polygon fill="none" stroke="black" points="181.75,-57.5 0,-57.5 0,0 181.75,0 181.75,-57.5"/>
# <text text-anchor="middle" x="90.88" y="-40.2" font-family="Times,serif" font-size="14.00">CSV SCAN ../data/titanic.csv;</text>
# <text text-anchor="middle" x="90.88" y="-23.7" font-family="Times,serif" font-size="14.00">π */12;</text>
# <text text-anchor="middle" x="90.88" y="-7.2" font-family="Times,serif" font-size="14.00">σ &#45;</text>
# </g>
# <!-- AGG [col(&quot;Age&quot;).mean()]
# BY
# [col(&quot;Pclass&quot;)] [(0, 0)] [(0, 0)]&#45;&#45;CSV SCAN ../data/titanic.csv;
# π */12;
# σ &#45; [(0, 1)] -->
# <g id="edge1" class="edge">
# <title>AGG [col(&quot;Age&quot;).mean()]
# BY
# [col(&quot;Pclass&quot;)] [(0, 0)] [(0, 0)]&#45;&#45;CSV SCAN ../data/titanic.csv;
# π */12;
# σ &#45; [(0, 1)]</title>
# <path fill="none" stroke="black" d="M90.88,-93.3C90.88,-82.05 90.88,-69.11 90.88,-57.84"/>
# </g>
# </g>
# </svg>

# %% [markdown]
# ### Query optimizations
# We print the optimized plan for this groupby query

# %%
print(
    pl.scan_csv(csvFile)
    .groupby('Pclass')
    .agg(
        pl.col("Age").mean()
    )
    .explain()
)
# Out:
# AGGREGATE
# 	[col("Age").mean()] BY [col("Pclass")] FROM
#
#   CSV SCAN ../data/titanic.csv
#   PROJECT 2/12 COLUMNS

# %% [markdown]
# In the optimized plan we have:
# - `PROJECT 2/12 COLUMNS` so Polars will only read the `Pclass` and `Age` columns from the CSV
# - `Aggregate [col("Age").mean()] BY [col("Pclass")]` so Polars will group by the `Pclass` column and take the `mean` of the `Age` column
#
# As with any lazy query we can evaluate this either all-at-once or in batches using streaming. To evaluate all-at-once call `collect` and to evaluate with streaming call `collect(streaming=True)

# %%
(
    pl.scan_csv(csvFile)
    .groupby('Pclass')
    .agg(
        pl.col("Age").mean()
    )
    .collect(streaming=True)
)
# Out:
# shape: (3, 2)
# ┌────────┬───────────┐
# │ Pclass ┆ Age       │
# │ ---    ┆ ---       │
# │ i64    ┆ f64       │
# ╞════════╪═══════════╡
# │ 2      ┆ 29.87763  │
# │ 1      ┆ 38.233441 │
# │ 3      ┆ 25.14062  │
# └────────┴───────────┘

# %% [markdown]
# In the chart we see that the time required for:
# - optimization of the query is relatively small
# - doing the groupby aggregation (in PIPELINE) is the largest component and
# - the sort at the end takes a non negligible amount of time (about 10% of the total)
#
# ## Exercises
# In the exercises you will develop your understanding of:
# - creating a `LazyGroupBy`
# - doing an aggregation on a `LazyGroupBy`
# - interpreting optimized query plans
#
# ## Exercise 1
# Create a `LazyGroupBy` on the `Survived` and `Plcass` columns in a query that starts with scanning the CSV

# %% [markdown]
# Aggregate the data by getting the minimum, average and maximum age per group

# %% [markdown]
# Evaluate the query

# %% [markdown]
# ## Solutions
#
# ## Solution to Exercise 1
# Create a `LazyGroupBy` on the `Survived` and `Plcass` columns in a query that starts with scanning the CSV

# %%
(
    pl.scan_csv(csvFile)
    .groupby(["Survived","Pclass"])
)

# %% [markdown]
# Exercise 1 cont: Aggregate the data by getting the minimum, average and maximum age per group

# %%
(
    pl.scan_csv(csvFile)
    .groupby(["Survived","Pclass"])
    .agg(
        [
            pl.col("Age").min().suffix("_min"),
            pl.col("Age").mean().suffix("_mean"),
            pl.col("Age").max().suffix("_max"),
        ]
    )
)

# %% [markdown]
# Exercise 1 cont: Evaluate the query

# %%
(
    pl.scan_csv(csvFile)
    .groupby(["Survived","Pclass"])
    .agg(
        [
            pl.col("Age").min().suffix("_min"),
            pl.col("Age").mean().suffix("_mean"),
            pl.col("Age").max().suffix("_max"),
        ]
    )
    .collect()
)
